# %%
import pandas as pd
import numpy as np

# %%
amazon = pd.read_csv('Datasets/amazon_prime_titles-score.csv')
amazon.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
amazon.insert(0, 'id', 'a' + amazon['show_id'])

amazon.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  Movie   The Grand Seduction    Don McKellar
# 1  as2      s2  Movie  Take Care Good Night    Girish Joshi
# 2  as3      s3  Movie  Secrets of Deception     Josh Webber
# 3  as4      s4  Movie    Pink: Staying True  Sonia Anderson
# 4  as5      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
disney = pd.read_csv('Datasets/disney_plus_titles-score.csv')
disney.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
disney.insert(0, 'id', 'd' + disney['show_id'])

disney.head()
# Out:
#     id show_id     type                                             title  \
# 0  ds1      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1  ds2      s2    Movie                            Ernest Saves Christmas
# 2  ds3      s3    Movie                      Ice Age: A Mammoth Christmas
# 3  ds4      s4    Movie                        The Queen Family Singalong
# 4  ds5      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
hulu = pd.read_csv('Datasets/hulu_titles-score (2).csv')
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description  score
# ...

# %%
hulu.insert(0, 'id', 'h' + hulu['show_id'])

hulu.head()
# Out:
#     id show_id   type                           title director  cast country  \
# 0  hs1      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1  hs2      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2  hs3      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3  hs4      s4  Movie                            Gaia      NaN   NaN     NaN
# 4  hs5      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
# ...

# %%
netflix = pd.read_csv('Datasets/netflix_titles-score.csv')
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.insert(0, 'id', 'n' + netflix['show_id'])

netflix.head()
# Out:
#     id show_id     type                  title         director  \
# 0  ns1      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  ns2      s2  TV Show          Blood & Water              NaN
# 2  ns3      s3  TV Show              Ganglands  Julien Leclercq
# 3  ns4      s4  TV Show  Jailbirds New Orleans              NaN
# 4  ns5      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
tablaFinal = pd.concat([amazon, disney, hulu, netflix], axis=0)

# %%
tablaFinal = tablaFinal.drop("show_id", axis=1)
tablaFinal
# Out:
#           id     type                 title         director  \
# 0        as1    Movie   The Grand Seduction     Don McKellar
# 1        as2    Movie  Take Care Good Night     Girish Joshi
# 2        as3    Movie  Secrets of Deception      Josh Webber
# 3        as4    Movie    Pink: Staying True   Sonia Anderson
# 4        as5    Movie         Monster Maker     Giles Foster
# ...      ...      ...                   ...              ...
# 8802  ns8803    Movie                Zodiac    David Fincher
# 8803  ns8804  TV Show           Zombie Dumb              NaN
# 8804  ns8805    Movie            Zombieland  Ruben Fleischer
# 8805  ns8806    Movie                  Zoom     Peter Hewitt
# 8806  ns8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
tablaFinal['rating'] = tablaFinal['rating'].fillna('G')

# %%
tablaFinal['date_added'] = pd.to_datetime(tablaFinal['date_added'])
tablaFinal['date_added'] = tablaFinal['date_added'].dt.strftime('%Y-%m-%d')
tablaFinal
# Out:
#           id     type                 title         director  \
# 0        as1    Movie   The Grand Seduction     Don McKellar
# 1        as2    Movie  Take Care Good Night     Girish Joshi
# 2        as3    Movie  Secrets of Deception      Josh Webber
# 3        as4    Movie    Pink: Staying True   Sonia Anderson
# 4        as5    Movie         Monster Maker     Giles Foster
# ...      ...      ...                   ...              ...
# 8802  ns8803    Movie                Zodiac    David Fincher
# 8803  ns8804  TV Show           Zombie Dumb              NaN
# 8804  ns8805    Movie            Zombieland  Ruben Fleischer
# 8805  ns8806    Movie                  Zoom     Peter Hewitt
# 8806  ns8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
tablaFinal[['duration_int', 'duration_type']] = tablaFinal['duration'].str.extract('(\d+)\s*(\w+)')
tablaFinal
# Out:
#           id     type                 title         director  \
# 0        as1    Movie   The Grand Seduction     Don McKellar
# 1        as2    Movie  Take Care Good Night     Girish Joshi
# 2        as3    Movie  Secrets of Deception      Josh Webber
# 3        as4    Movie    Pink: Staying True   Sonia Anderson
# 4        as5    Movie         Monster Maker     Giles Foster
# ...      ...      ...                   ...              ...
# 8802  ns8803    Movie                Zodiac    David Fincher
# 8803  ns8804  TV Show           Zombie Dumb              NaN
# 8804  ns8805    Movie            Zombieland  Ruben Fleischer
# 8805  ns8806    Movie                  Zoom     Peter Hewitt
# 8806  ns8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
# Convierte los valores de las columnas a minúsculas
tablaFinal['type'] = tablaFinal['type'].str.lower()
tablaFinal['title'] = tablaFinal['title'].str.lower()
tablaFinal['director'] = tablaFinal['director'].str.lower()
tablaFinal['cast'] = tablaFinal['cast'].str.lower()
tablaFinal['country'] = tablaFinal['country'].str.lower()
tablaFinal['listed_in'] = tablaFinal['listed_in'].str.lower()
tablaFinal['description'] = tablaFinal['description'].str.lower()
tablaFinal['duration_type'] = tablaFinal['duration_type'].str.lower()
tablaFinal
# Out:
#           id     type                 title         director  \
# 0        as1    movie   the grand seduction     don mckellar
# 1        as2    movie  take care good night     girish joshi
# 2        as3    movie  secrets of deception      josh webber
# 3        as4    movie    pink: staying true   sonia anderson
# 4        as5    movie         monster maker     giles foster
# ...      ...      ...                   ...              ...
# 8802  ns8803    movie                zodiac    david fincher
# 8803  ns8804  tv show           zombie dumb              NaN
# 8804  ns8805    movie            zombieland  ruben fleischer
# 8805  ns8806    movie                  zoom     peter hewitt
# 8806  ns8807    movie                zubaan      mozez singh
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# ...

# %%
tablaFinal = tablaFinal.drop("duration", axis=1)
tablaFinal

# %%
#Creamos la columna llamada platform
tablaFinal["platform"] = tablaFinal["id"].str[0].map({
    "a": "amazon",
    "d": "disney",
    "h": "hulu",
    "n": "netflix"
})

# %%
# Reemplazar los valores no finitos por cero
tablaFinal['duration_int'] = tablaFinal['duration_int'].fillna(0)

# Convertir la columna a tipo integer
tablaFinal['duration_int'] = tablaFinal['duration_int'].astype(int)

# %%
tablaFinal['duration_type'] = tablaFinal['duration_type'].astype(str)

# %%
tablaFinal.to_csv('plataformas.csv', index=False)

# %%
plataformas_df = pd.read_csv('plataformas.csv')
plataformas_df
# Out:
#            id     type                 title         director  \
# 0         as1    movie   the grand seduction     don mckellar
# 1         as2    movie  take care good night     girish joshi
# 2         as3    movie  secrets of deception      josh webber
# 3         as4    movie    pink: staying true   sonia anderson
# 4         as5    movie         monster maker     giles foster
# ...       ...      ...                   ...              ...
# 22993  ns8803    movie                zodiac    david fincher
# 22994  ns8804  tv show           zombie dumb              NaN
# 22995  ns8805    movie            zombieland  ruben fleischer
# 22996  ns8806    movie                  zoom     peter hewitt
# 22997  ns8807    movie                zubaan      mozez singh
#
#                                                     cast         country  \
# 0         brendan gleeson, taylor kitsch, gordon pinsent          canada
# ...

# %%
plataformas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22998 entries, 0 to 22997
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             22998 non-null  object
#  1   type           22998 non-null  object
#  2   title          22998 non-null  object
#  3   director       14739 non-null  object
#  4   cast           17677 non-null  object
#  5   country        11499 non-null  object
#  6   date_added     13444 non-null  object
#  7   release_year   22998 non-null  int64
#  8   rating         22998 non-null  object
#  9   listed_in      22998 non-null  object
#  10  description    22994 non-null  object
#  11  score          22998 non-null  int64
#  12  duration_int   22998 non-null  int64
#  13  duration_type  22516 non-null  object
#  14  platform       22998 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 2.6+ MB

# %%
#Las siguientes funciones son las que ejecutaremos en la API.

#Cantidad de veces que aparece una keyword en el título de peliculas/series, por plataforma

def get_word_count(keyword, plataforma):
    
    keyword = keyword.lower()
    plataforma = plataforma.lower()

    cantidad = ((plataformas_df['platform'] == plataforma) & (plataformas_df['title'].str.contains(keyword))).sum()
    cantidad = int(cantidad)

    if cantidad == 0:
        return ('La palabra ' + keyword + ' no se encuentra en los titulos de ' + plataforma.capitalize())
    elif cantidad == 1:
        return ('La palabra ' + keyword + ' se encuentra 1(una) vez en los titulos de ' + plataforma.capitalize())
    elif cantidad > 1:
        return ('La palabra ' + keyword + ' se encuentra ' + str(cantidad) + ' veces en los titulos de ' + plataforma.capitalize())

# %%
get_word_count('death', 'amazon')
# Out:
# 'La palabra death se encuentra 46 veces en los titulos de Amazon'

# %%
#Cantidad de películas por plataforma con un puntaje mayor a XX en determinado año

def get_score_count(plataforma, puntaje, anio):

    cantidad = ((plataformas_df['platform'] == plataforma) & (plataformas_df['score'] > puntaje) & (plataformas_df['release_year'] == anio) & (plataformas_df['duration_type'] == "min")).sum()

    if cantidad == 0:
        return ('No se encontraron peliculas con mas de ' + str(puntaje) + ' puntos en ' + plataforma.capitalize())
    elif cantidad == 1:
        return ('Se encontro 1(una) pelicula con mas de ' + str(puntaje) + ' puntos en ' + plataforma.capitalize())
    elif cantidad > 1:
        return ('Se encontraron ' + str(cantidad) + ' peliculas con mas de ' + str(puntaje) + ' puntos en ' + plataforma.capitalize())

# %%
get_score_count('disney', 99, 2014)
# Out:
# 'No se encontraron peliculas con mas de 99 puntos en Disney'

# %%
#La segunda película con mayor score para una plataforma determinada, según el orden alfabético de los títulos.

def get_second_score(plataforma):

    resultado = plataformas_df[(plataformas_df['type'] == 'movie') & (plataformas_df['platform']== plataforma)]

    max_score = resultado['score'].max()
    pelicula = resultado[resultado['score'] == max_score]['title']
    pelicula = pelicula.to_list()
    pelicula = sorted(pelicula)
    pelicula = pelicula[1]
    
    return str(pelicula), str(max_score)

# %%
get_second_score('amazon')
# Out:
# ('abilene town', '100')

# %%
#Película que más duró según año, plataforma y tipo de duración

def get_longest(plataforma, min_o_season, anio):
    resultado = plataformas_df[(plataformas_df['platform']==plataforma) & (plataformas_df['release_year']==anio) & (plataformas_df['duration_type'] == min_o_season)]

    max_duration = resultado['duration_int'].max()
    pelicula = resultado[resultado['duration_int'] == max_duration]['title']
    pelicula = pelicula.to_list()
    pelicula = pelicula[0]
    return pelicula, str(max_duration) + ' ' + str(min_o_season)

# %%
get_longest('netflix', 'min', 2012)
# Out:
# ('cloud atlas', '172 min')

# %%
#Cantidad de series y películas por rating

def get_rating_count(rating):
        cantidad = (plataformas_df['rating'].str.contains(rating)).sum()
        return rating, int(cantidad)

# %%
get_rating_count('13+')
# Out:
# ('13+', 3231)
